# %%
import pandas as pd
import numpy as np

# %%
dtrain = pd.read_csv('data/train.csv')

# %%
dtrain['song_id'].unique().shape
# Out:
# (359966,)

# %%
dtrain.shape
# Out:
# (7377418, 6)

# %%
dtrain
# Out:
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 10       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 11       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 12       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 13       3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 14       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 15       3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# ...

# %%
dsongs = pd.read_csv('data/songs.csv')

# %%
dsongs['song_id'].unique().shape
# Out:
# (2296320,)

# %%
dsongs.shape
# Out:
# (2296320, 7)

# %%
# 合并数据
dmerge = pd.merge(dtrain, dsongs, on='song_id', how='left')

# %%
dtrain.head(0)
# Out:
# Empty DataFrame
# Columns: [msno, song_id, source_system_tab, source_screen_name, source_type, target]
# Index: []

# %%
dsongs.head(0)
# Out:
# Empty DataFrame
# Columns: [song_id, song_length, genre_ids, artist_name, composer, lyricist, language]
# Index: []

# %%
dmerge.head(0)
# Out:
# Empty DataFrame
# Columns: [msno, song_id, source_system_tab, source_screen_name, source_type, target, song_length, genre_ids, artist_name, composer, lyricist, language]
# Index: []

# %%
dmerge.shape
# Out:
# (7377418, 12)

# %%
dmerge[dmerge.song_id == 'JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=']
# Out:
#                                                  msno  \
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 1614787  O7OWTSBR3kYP6neyMMy5+u9mUFgIN4iFETbDgzB2YQM=
# 5775707  BBox7sGGCdPkB12i3nWaMAv/ggYUEtfOWKkrbRMb3gk=
# 6287426  frZtrrN1Y2ZqZX3VFiq7FpAvLth3kZJNovT9cmyn2O4=
#
#                                               song_id source_system_tab  \
# 2        JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 1614787  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 5775707  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=             radio
# 6287426  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=             radio
#
#           source_screen_name     source_type  target  song_length genre_ids  \
# 2        Local playlist more  local-playlist       1     225396.0      1259
# 1614787  Local playlist more  local-playlist       1     225396.0      1259
# 5775707                Radio           radio       0     225396.0      1259
# ...

# %%
dsongs[dsongs.song_id == 'JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=']
# Out:
#                                              song_id  song_length genre_ids  \
# 456722  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=       225396      1259
#
#        artist_name                              composer lyricist  language
# 456722         Nas  N. Jones、W. Adams、J. Lordan、D. Ingle      NaN      52.0
