# %%
import pandas as pd
import numpy as np
data_path = '../data/'

# %%
dtrain = pd.read_csv(data_path + 'train.csv')
dtest = pd.read_csv(data_path + 'test.csv')
dsongs = pd.read_csv(data_path + 'songs.csv')
dsong_extra = pd.read_csv(data_path + 'song_extra_info.csv')
dmembers = pd.read_csv(data_path + 'members.csv')

# %%
# merge data
train = dtrain.merge(dsongs, on='song_id', how='left')

# %%
dtest = train.loc[0:99, :]

# %%
# map string to numeric
def string_to_numeric(dataframe, column_in):
#     series_in = dataframe[column_in]
    dataframe.sort_values(by=dataframe[column_in].name, na_position='first', inplace=True)
    dataframe_dict=dict(zip(dataframe[column_in].unique(), range(len(dataframe[column_in].unique()))))
    dataframe.loc[:, dataframe[column_in].name] = dataframe[column_in].map(dataframe_dict)

# %%
for column in ['source_system_tab', 'source_screen_name']:
#     print(column)
    string_to_numeric(dtest, column)
# Out:
# /Users/shangyingao/anaconda3/envs/irhd/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/shangyingao/anaconda3/envs/irhd/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# # other try

# %%
dtrain.head(0)
# Out:
# Empty DataFrame
# Columns: [msno, song_id, source_system_tab, source_screen_name, source_type, target]
# Index: []

# %%
train.head(0)
# Out:
# Empty DataFrame
# Columns: [msno, song_id, source_system_tab, source_screen_name, source_type, target, song_length, genre_ids, artist_name, composer, lyricist, language]
# Index: []

# %%
train.artist_name.value_counts().sort_values(ascending=False).head()
# Out:
# Various Artists    303616
# 周杰倫 (Jay Chou)     186776
# 五月天 (Mayday)       182088
# 林俊傑 (JJ Lin)       115325
# 田馥甄 (Hebe)         104946
# Name: artist_name, dtype: int64

# %%
train.composer.value_counts().sort_values(ascending=False).head()
# Out:
# 周杰倫       201910
# 阿信         90343
# 林俊傑        78606
# 陳皓宇        58837
# JJ Lin     48089
# Name: composer, dtype: int64

# %%
train.convert_objects(convert_numeric=True)
# Out:
# /Users/shangyingao/anaconda3/envs/irhd/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 10       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# ...

# %%
train.loc[0:100,:]
# Out:
#                                              msno  \
# 0    FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1    Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2    Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3    Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4    FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5    FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6    Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7    FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8    uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9    uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 10   uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 11   uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 12   TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 13   3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 14   TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 15   3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 16   TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 17   TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# ...
